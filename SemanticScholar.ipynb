# %% [markdown]
# ## Preparing the arXiv ID for SS

# %%
import re 

datas = []
unmatch = []
# Regular expression pattern to find and capture the numerical parts
pattern = r"https://arxiv.org/pdf/(\d{4}\.\d{5})\.pdf"


with open('data/reason.md', 'r') as f:
    for line in f.readlines():  
        if 'https://arxiv' in line:
            # Find all matches in the string
            matches = re.findall(pattern, line)
            datas.append(f'ARXIV:{matches[0]}')
        elif 'pdf' in line:
            unmatch.append(line)

datas[:5]
# Out:
# ['ARXIV:2309.13625',
#  'ARXIV:2310.13023',
#  'ARXIV:2310.04560',
#  'ARXIV:2310.04944',
#  'ARXIV:2310.00299']

# %% [markdown]
# ## Get TL;DR from SemanticScholar

# %%
from semanticscholar import SemanticScholar
sch = SemanticScholar()

# %%
def get_meta_data(paper):
    domains = ['title', 'authors', 'abstract', 'tldr', 'venue', 'referenceCount', 'citationCount', 'influentialCitationCount']

    meta_data = {}
    for domain in domains:
        if domain in paper.keys():
            if domain == 'authors':
                authors = []
                for author_domain in paper.__getattribute__(domain):
                    authors.append(author_domain['name'])
                meta_data['authors'] = authors
            else:
                domain_res = paper.__getattribute__(domain)
                if domain == 'tldr':
                    domain_res = str(domain_res)
                meta_data[domain] = domain_res
    return meta_data

# %%
from tqdm import tqdm 
import time

meta_datas = []
with open('result.json', 'a+') as fp:
    for data in tqdm(datas):
        try:
            paper = sch.get_paper(data)
            fp.writelines(get_meta_data(paper))
        except:
            fp.writelines({'Cannot find': data})
        
        meta_datas.append(get_meta_data(paper))
        time.sleep(2) # hold 2 sec
# Out:
#   0%|          | 0/111 [00:19<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/34/f44w08g92cddctb47s9_02jw0000gn/T/ipykernel_47115/752272656.py in <module>
#      11             fp.writelines({'Cannot find': data})
#      12
# ---> 13         meta_datas.append(get_meta_data(paper))
#      14         time.sleep(2) # hold 2 sec
#
# NameError: name 'paper' is not defined

# %% [markdown]
# ## arXiv searching

# %%
import arxiv

# Construct the default API client.
client = arxiv.Client()

# Search for the 10 most recent articles matching the keyword "quantum."
# -----
# sort_by
# Relevance 
# LastUpdatedDate 
# SubmittedDate
# -----
# order
# Ascending
# Descending

search = arxiv.Search(
  query = "Large Language Models; Planning",
  max_results = 500,
  sort_by = arxiv.SortCriterion.SubmittedDate,
  sort_order = arxiv.SortOrder.Descending,
)

results = client.results(search)
# for r in client.results(search):
#   print(r.title, r.published)

# %%
from tqdm import tqdm 

res = []
for r in tqdm(results, total=500):
    res.append(f'[arXiv {r.published.year}.{r.published.month:02d}] ' + r.title + f'[[paper]]({r.links[-1].href})')
# Out:
# 100%|██████████| 500/500 [00:34<00:00, 14.38it/s]

# %%
for paper_info in res:
    print(paper_info)
# Out:
# [arXiv 2024.07] LLaVA-NeXT-Interleave: Tackling Multi-image, Video, and 3D in Large Multimodal Models[[paper]](http://arxiv.org/pdf/2407.07895v1)
# [arXiv 2024.07] Training on the Test Task Confounds Evaluation and Emergence[[paper]](http://arxiv.org/pdf/2407.07890v1)
# [arXiv 2024.07] AdaptiGraph: Material-Adaptive Graph-Based Neural Dynamics for Robotic Manipulation[[paper]](http://arxiv.org/pdf/2407.07889v1)
# [arXiv 2024.07] Self-similar Markov trees and scaling limits[[paper]](http://arxiv.org/pdf/2407.07888v1)
# [arXiv 2024.07] Learning In-Hand Translation Using Tactile Skin With Shear and Normal Force Sensing[[paper]](http://arxiv.org/pdf/2407.07885v1)
# [arXiv 2024.07] Information dynamics in decohered quantum memory with repeated syndrome measurements: a dual approach[[paper]](http://arxiv.org/pdf/2407.07882v1)
# [arXiv 2024.07] Towards Robust Alignment of Language Models: Distributionally Robustifying Direct Preference Optimization[[paper]](http://arxiv.org/pdf/2407.07880v1)
# [arXiv 2024.07] Bound States in Continuum via Singular Transfer Matrices[[paper]](http://arxiv.org/pdf/2407.07879v1)
# [arXiv 2024.07] Generative Image as Action Models[[paper]](http://arxiv.org/pdf/2407.07875v1)
# [arXiv 2024.07] Toto: Time Series Optimized Transformer for Observability[[paper]](http://arxiv.org/pdf/2407.07874v2)
# [arXiv 2024.07] Dynamical Measure Transport and Neural PDE Solvers for Sampling[[paper]](http://arxiv.org/pdf/2407.07873v1)
# [arXiv 2024.07] Enhancing HNSW Index for Real-Time Updates: Addressing Unreachable Points and Performance Degradation[[paper]](http://arxiv.org/pdf/2407.07871v1)
# [arXiv 2024.07] High-resolution Elemental Abundance Measurements of Cool JWST Planet Hosts Using AutoSpecFit: An Application to the Sub-Neptune K2-18b's Host M dwarf[[paper]](http://arxiv.org/pdf/2407.07869v1)
# [arXiv 2024.07] Shocks and instability in Brownian last-passage percolation[[paper]](http://arxiv.org/pdf/2407.07866v1)
# [arXiv 2024.07] The principled-parameterized approach to gravitational collapse[[paper]](http://arxiv.org/pdf/2407.07862v1)
# [arXiv 2024.07] Controlling Space and Time with Diffusion Models[[paper]](http://arxiv.org/pdf/2407.07860v1)
# [arXiv 2024.07] FACTS About Building Retrieval Augmented Generation-based Chatbots[[paper]](http://arxiv.org/pdf/2407.07858v1)
# [arXiv 2024.07] RG Interfaces from Double-Trace Deformations[[paper]](http://arxiv.org/pdf/2407.07856v1)
# [arXiv 2024.07] Progressive Growing of Patch Size: Resource-Efficient Curriculum Learning for Dense Prediction Tasks[[paper]](http://arxiv.org/pdf/2407.07853v2)
# [arXiv 2024.07] OpenDiLoCo: An Open-Source Framework for Globally Distributed Low-Communication Training[[paper]](http://arxiv.org/pdf/2407.07852v1)
# [arXiv 2024.07] Scaling limit of domino tilings on a pentagonal domain[[paper]](http://arxiv.org/pdf/2407.07849v1)
# [arXiv 2024.07] Uncovering Layer-Dependent Activation Sparsity Patterns in ReLU Transformers[[paper]](http://arxiv.org/pdf/2407.07848v1)
# [arXiv 2024.07] Litmus tests of the flat $Λ$CDM model and model-independent measurement of $H_0r_\mathrm{d}$[[paper]](http://arxiv.org/pdf/2407.07847v1)
# [arXiv 2024.07] Natural Language Mechanisms via Self-Resolution with Foundation Models[[paper]](http://arxiv.org/pdf/2407.07845v1)
# [arXiv 2024.07] OV-DINO: Unified Open-Vocabulary Detection with Language-Aware Selective Fusion[[paper]](http://arxiv.org/pdf/2407.07844v1)
# [arXiv 2024.07] Study on Aspect Ratio Variability toward Robustness of Vision Transformer-based Vehicle Re-identification[[paper]](http://arxiv.org/pdf/2407.07842v1)
# [arXiv 2024.07] Benchmarking Embedding Aggregation Methods in Computational Pathology: A Clinical Data Perspective[[paper]](http://arxiv.org/pdf/2407.07841v1)
# [arXiv 2024.07] Decompose and Compare Consistency: Measuring VLMs' Answer Reliability via Task-Decomposition Consistency Comparison[[paper]](http://arxiv.org/pdf/2407.07840v1)
# [arXiv 2024.07] Galactic Halos and rotating bosonic dark matter[[paper]](http://arxiv.org/pdf/2407.07839v1)
# [arXiv 2024.07] Probe and Prejudice: Classification of compact objects and model comparison using EOS knowledge[[paper]](http://arxiv.org/pdf/2407.07837v1)
# [arXiv 2024.07] RoBus: A Multimodal Dataset for Controllable Road Networks and Building Layouts Generation[[paper]](http://arxiv.org/pdf/2407.07835v1)
# [arXiv 2024.07] Generic Numerical Analysis of Stochastic Reaction Diffusion Model with applications in excitable media[[paper]](http://arxiv.org/pdf/2407.07834v1)
# [arXiv 2024.07] Viscoelastic dip-coating beyond lubrication theory[[paper]](http://arxiv.org/pdf/2407.07833v1)
# [arXiv 2024.07] Dynamical signatures of discontinuous phase transitions: How phase coexistence determines exponential versus power-law scaling[[paper]](http://arxiv.org/pdf/2407.07832v1)
# [arXiv 2024.07] Wilson Loops and Spherical Branes[[paper]](http://arxiv.org/pdf/2407.07830v1)
# [arXiv 2024.07] Disentangled Representation Learning through Geometry Preservation with the Gromov-Monge Gap[[paper]](http://arxiv.org/pdf/2407.07829v1)
# [arXiv 2024.07] Inhibition of splitting of the chiral and deconfinement transition due to rotation in QCD: the phase diagram of linear sigma model coupled to Polyakov loop[[paper]](http://arxiv.org/pdf/2407.07828v1)
# [arXiv 2024.07] Estimating the stability number of a random graph using convolutional neural networks[[paper]](http://arxiv.org/pdf/2407.07827v1)
# [arXiv 2024.07] Using Activity to Compartmentalize Binary Mixtures[[paper]](http://arxiv.org/pdf/2407.07826v1)
# [arXiv 2024.07] RT-LA-VocE: Real-Time Low-SNR Audio-Visual Speech Enhancement[[paper]](http://arxiv.org/pdf/2407.07825v1)
# [arXiv 2024.07] Bayesian Inference of Fine-Features of Nuclear Equation of State from Future Neutron Star Radius Measurements to 0.1km Accuracy[[paper]](http://arxiv.org/pdf/2407.07823v1)
# [arXiv 2024.07] When to Accept Automated Predictions and When to Defer to Human Judgment?[[paper]](http://arxiv.org/pdf/2407.07821v1)
# [arXiv 2024.07] Friction through molecular adsorption at the sliding interface of hydrogels: Theory and experiments[[paper]](http://arxiv.org/pdf/2407.07819v1)
# [arXiv 2024.07] The Misclassification Likelihood Matrix: Some Classes Are More Likely To Be Misclassified Than Others[[paper]](http://arxiv.org/pdf/2407.07818v1)
# [arXiv 2024.07] Daisy: An integrated repeat protein curation service[[paper]](http://arxiv.org/pdf/2407.07817v1)
# [arXiv 2024.07] Optimal sampling for least squares approximation with general dictionaries[[paper]](http://arxiv.org/pdf/2407.07814v1)
# [arXiv 2024.07] Dispersive determination of the fourth generation lepton masses[[paper]](http://arxiv.org/pdf/2407.07813v1)
# [arXiv 2024.07] A Numerical Calculation of Entanglement Entropy in de Sitter Space[[paper]](http://arxiv.org/pdf/2407.07811v1)
# [arXiv 2024.07] Transformer Alignment in Large Language Models[[paper]](http://arxiv.org/pdf/2407.07810v1)
# [arXiv 2024.07] Direct estimation and inference of higher-level correlations from lower-level measurements with applications in gene-pathway and proteomics studies[[paper]](http://arxiv.org/pdf/2407.07809v1)
# [arXiv 2024.07] Revisiting the dead time effects of Insight-HXMT/ME on timing analysis[[paper]](http://arxiv.org/pdf/2407.07807v1)
# [arXiv 2024.07] SUMix: Mixup with Semantic and Uncertain Information[[paper]](http://arxiv.org/pdf/2407.07805v1)
# [arXiv 2024.07] Call Graph Soundness in Android Static Analysis[[paper]](http://arxiv.org/pdf/2407.07804v1)
# [arXiv 2024.07] ROSA: Random Subspace Adaptation for Efficient Fine-Tuning[[paper]](http://arxiv.org/pdf/2407.07802v1)
# [arXiv 2024.07] AVCap: Leveraging Audio-Visual Features as Text Tokens for Captioning[[paper]](http://arxiv.org/pdf/2407.07801v2)
# [arXiv 2024.07] Jump Plus AM-FM Mode Decomposition[[paper]](http://arxiv.org/pdf/2407.07800v1)
# [arXiv 2024.07] Attribute or Abstain: Large Language Models as Long Document Assistants[[paper]](http://arxiv.org/pdf/2407.07799v1)
# [arXiv 2024.07] Evaluating Large Language Models with Grid-Based Game Competitions: An Extensible LLM Benchmark and Leaderboard[[paper]](http://arxiv.org/pdf/2407.07796v2)
# [arXiv 2024.07] Flooding Spread of Manipulated Knowledge in LLM-Based Multi-Agent Communities[[paper]](http://arxiv.org/pdf/2407.07791v1)
# [arXiv 2024.07] Systematic Evaluation of Neural Retrieval Models on the Touché 2020 Argument Retrieval Subset of BEIR[[paper]](http://arxiv.org/pdf/2407.07790v1)
# [arXiv 2024.07] Raising the Ceiling: Conflict-Free Local Feature Matching with Dynamic View Switching[[paper]](http://arxiv.org/pdf/2407.07789v1)
# [arXiv 2024.07] Multiparameter admittance spectroscopy for investigating defects in MoS${_2}$ thin film MOSFETs[[paper]](http://arxiv.org/pdf/2407.07783v1)
# [arXiv 2024.07] Universal and non-universal signatures in the scaling functions of critical variables[[paper]](http://arxiv.org/pdf/2407.07782v1)
# [arXiv 2024.07] Sequential Kalman Monte Carlo for gradient-free inference in Bayesian inverse problems[[paper]](http://arxiv.org/pdf/2407.07781v1)
# [arXiv 2024.07] Cross Domain Object Detection via Multi-Granularity Confidence Alignment based Mean Teacher[[paper]](http://arxiv.org/pdf/2407.07780v1)
# [arXiv 2024.07] WorldAPIs: The World Is Worth How Many APIs? A Thought Experiment[[paper]](http://arxiv.org/pdf/2407.07778v1)
# [arXiv 2024.07] Diphoton signals for the Georgi-Machacek scenario at the Large Hadron Collider[[paper]](http://arxiv.org/pdf/2407.07776v2)
# [arXiv 2024.07] Mobility VLA: Multimodal Instruction Navigation with Long-Context VLMs and Topological Graphs[[paper]](http://arxiv.org/pdf/2407.07775v1)
# [arXiv 2024.07] On a Casselman-Shalika type formula for unramified Speh representations[[paper]](http://arxiv.org/pdf/2407.07774v1)
# [arXiv 2024.07] Finite Blocklength Performance of Capacity-achieving Codes in the Light of Complexity Theory[[paper]](http://arxiv.org/pdf/2407.07773v1)
# [arXiv 2024.07] Multi-task Prompt Words Learning for Social Media Content Generation[[paper]](http://arxiv.org/pdf/2407.07771v1)
# [arXiv 2024.07] Challenges in modeling the dark matter halo of NGC 1052-DF2: Cored versus cuspy halo models[[paper]](http://arxiv.org/pdf/2407.07770v1)
# [arXiv 2024.07] HSTPROMO Internal Proper Motion Kinematics of Dwarf Spheroidal Galaxies: I. Velocity Anisotropy and Dark Matter Cusp Slope of Draco[[paper]](http://arxiv.org/pdf/2407.07769v1)
# [arXiv 2024.07] Ramsey Theorems for Trees and a General 'Private Learning Implies Online Learning' Theorem[[paper]](http://arxiv.org/pdf/2407.07765v1)
# [arXiv 2024.07] PosFormer: Recognizing Complex Handwritten Mathematical Expression with Position Forest Transformer[[paper]](http://arxiv.org/pdf/2407.07764v1)
# [arXiv 2024.07] S&D Messenger: Exchanging Semantic and Domain Knowledge for Generic Semi-Supervised Medical Image Segmentation[[paper]](http://arxiv.org/pdf/2407.07763v1)
# [arXiv 2024.07] Unveiling the ice and gas nature of active centaur (2060) Chiron using the James Webb Space Telescope[[paper]](http://arxiv.org/pdf/2407.07761v1)
# [arXiv 2024.07] Learning Spatial-Semantic Features for Robust Video Object Segmentation[[paper]](http://arxiv.org/pdf/2407.07760v1)
# [arXiv 2024.07] Can ChatGPT Pass a Theory of Computing Course?[[paper]](http://arxiv.org/pdf/2407.07757v1)
# [arXiv 2024.07] ArcaNN: automated enhanced sampling generation of training sets for chemically reactive machine learning interatomic potentials[[paper]](http://arxiv.org/pdf/2407.07751v1)
# [arXiv 2024.07] Directed Transit Functions[[paper]](http://arxiv.org/pdf/2407.07741v1)
# [arXiv 2024.07] LSM: A Comprehensive Metric for Assessing the Safety of Lane Detection Systems in Autonomous Driving[[paper]](http://arxiv.org/pdf/2407.07740v1)
# [arXiv 2024.07] Fine-Tuning Large Language Models with User-Level Differential Privacy[[paper]](http://arxiv.org/pdf/2407.07737v1)
# [arXiv 2024.07] Prediction of Frequency-Dependent Optical Spectrum for Solid Materials: A Multi-Output & Multi-Fidelity Machine Learning Approach[[paper]](http://arxiv.org/pdf/2407.07736v1)
# [arXiv 2024.07] Protecting NeRFs' Copyright via Plug-And-Play Watermarking Base Model[[paper]](http://arxiv.org/pdf/2407.07735v1)
# [arXiv 2024.07] Unveiling the Asymmetry in Density within the Shear Bands of Metallic Glasses[[paper]](http://arxiv.org/pdf/2407.07733v1)
# [arXiv 2024.07] Large spin-orbit torque in a-plane $α$-Fe$_{2}$O$_{3}$/Pt bilayers[[paper]](http://arxiv.org/pdf/2407.07731v1)
# [arXiv 2024.07] Another reason why normalized gain should continue to be used to analyze concept inventories (and estimate learning rates)[[paper]](http://arxiv.org/pdf/2407.07730v1)
# [arXiv 2024.07] SaMoye: Zero-shot Singing Voice Conversion Based on Feature Disentanglement and Synthesis[[paper]](http://arxiv.org/pdf/2407.07728v2)
# [arXiv 2024.07] Thermoelectric cooling of a finite reservoir coupled to a quantum dot[[paper]](http://arxiv.org/pdf/2407.07727v1)
# [arXiv 2024.07] PaliGemma: A versatile 3B VLM for transfer[[paper]](http://arxiv.org/pdf/2407.07726v1)
# [arXiv 2024.07] High-Performance Sorting-Based k-mer Counting in Distributed Memory with Flexible Hybrid Parallelism[[paper]](http://arxiv.org/pdf/2407.07718v1)
# [arXiv 2024.07] High-dimensional Covariance Estimation by Pairwise Likelihood Truncation[[paper]](http://arxiv.org/pdf/2407.07717v1)
# [arXiv 2024.07] Relative Sensitivities and Correlation of Factors Introducing Uncertainty in Radiotherapy Dosimetry Audits[[paper]](http://arxiv.org/pdf/2407.07714v1)
# [arXiv 2024.07] Deep-Graph-Sprints: Accelerated Representation Learning in Continuous-Time Dynamic Graphs[[paper]](http://arxiv.org/pdf/2407.07712v1)
# [arXiv 2024.07] Motion simulation of radio-labeled cells in whole-body positron emission tomography[[paper]](http://arxiv.org/pdf/2407.07709v1)
# [arXiv 2024.07] Quark spin effects in $e^+e^-$ annihilation: a Monte Carlo event generator study[[paper]](http://arxiv.org/pdf/2407.07706v1)
# [arXiv 2024.07] Evaluating the Role of Security Assurance Cases in Agile Medical Device Development[[paper]](http://arxiv.org/pdf/2407.07704v1)
# [arXiv 2024.07] Split Conformal Prediction under Data Contamination[[paper]](http://arxiv.org/pdf/2407.07700v1)
# [arXiv 2024.07] Layer Resolved Magnetotransport Properties in Antiferromagnetic/Paramagnetic Superlattices[[paper]](http://arxiv.org/pdf/2407.07696v1)
# [arXiv 2024.07] Scalable, high-fidelity all-electronic control of trapped-ion qubits[[paper]](http://arxiv.org/pdf/2407.07694v1)
# [arXiv 2024.07] Discovery of MgS and NaS in the Interstellar Medium and tentative detection of CaO[[paper]](http://arxiv.org/pdf/2407.07693v1)
# [arXiv 2024.07] Spectral Statistics, Hydrodynamics and Quantum Chaos[[paper]](http://arxiv.org/pdf/2407.07692v1)
# [arXiv 2024.07] Direct Imaging of a Prolonged Plasma/Current Sheet and Quasiperiodic Magnetic Reconnection on the Sun[[paper]](http://arxiv.org/pdf/2407.07687v1)
# [arXiv 2024.07] Towards Human-Like Driving: Active Inference in Autonomous Vehicle Control[[paper]](http://arxiv.org/pdf/2407.07684v1)
# [arXiv 2024.07] The Language of Weather: Social Media Reactions to Weather Accounting for Climatic and Linguistic Baselines[[paper]](http://arxiv.org/pdf/2407.07683v1)
# [arXiv 2024.07] The ESO SupJup Survey II: The $^{12}$C/$^{13}$C ratios of three young brown dwarfs with CRIRES$^+$[[paper]](http://arxiv.org/pdf/2407.07678v1)
# [arXiv 2024.07] Competing aggregation and iso-density equilibrium lead to band pattern formation in density gradients[[paper]](http://arxiv.org/pdf/2407.07676v1)
# [arXiv 2024.07] Feasibility Study on Active Learning of Smart Surrogates for Scientific Simulations[[paper]](http://arxiv.org/pdf/2407.07674v1)
# [arXiv 2024.07] StoryDiffusion: How to Support UX Storyboarding With Generative-AI[[paper]](http://arxiv.org/pdf/2407.07672v1)
# [arXiv 2024.07] Why should we ever automate moral decision making?[[paper]](http://arxiv.org/pdf/2407.07671v1)
# [arXiv 2024.07] Stochastic Gradient Descent for Two-layer Neural Networks[[paper]](http://arxiv.org/pdf/2407.07670v1)
# [arXiv 2024.07] How to Leverage Predictive Uncertainty Estimates for Reducing Catastrophic Forgetting in Online Continual Learning[[paper]](http://arxiv.org/pdf/2407.07668v1)
# [arXiv 2024.07] VEnhancer: Generative Space-Time Enhancement for Video Generation[[paper]](http://arxiv.org/pdf/2407.07667v1)
# [arXiv 2024.07] A Proposed S.C.O.R.E. Evaluation Framework for Large Language Models : Safety, Consensus, Objectivity, Reproducibility and Explainability[[paper]](http://arxiv.org/pdf/2407.07666v1)
# [arXiv 2024.07] A Coding-Theoretic Analysis of Hyperspherical Prototypical Learning Geometry[[paper]](http://arxiv.org/pdf/2407.07664v1)
# [arXiv 2024.07] Mitigating Backdoor Attacks using Activation-Guided Model Editing[[paper]](http://arxiv.org/pdf/2407.07662v1)
# [arXiv 2024.07] Confirming the glueball-like particle $X(2370)$ productions in $e^+e^-$ collisions at BESIII energy with PACIAE model[[paper]](http://arxiv.org/pdf/2407.07661v1)
# [arXiv 2024.07] Co-designing heterogeneous models: a distributed systems approach[[paper]](http://arxiv.org/pdf/2407.07656v1)
# [arXiv 2024.07] AffectGPT: Dataset and Framework for Explainable Multimodal Emotion Recognition[[paper]](http://arxiv.org/pdf/2407.07653v1)
# [arXiv 2024.07] From traffic jams to roadblocks: The outer regions of TW Hya with ALMA Band 8[[paper]](http://arxiv.org/pdf/2407.07649v1)
# [arXiv 2024.07] Two Stage Least Squares with Time-Varying Instruments: An Application to an Evaluation of Treatment Intensification for Type-2 Diabetes[[paper]](http://arxiv.org/pdf/2407.07647v1)
# [arXiv 2024.07] A Practical Guide to Transcranial Ultrasonic Stimulation from the IFCN-endorsed ITRUSST Consortium[[paper]](http://arxiv.org/pdf/2407.07646v1)
# [arXiv 2024.07] On Sampling from Ising Models with Spectral Constraints[[paper]](http://arxiv.org/pdf/2407.07645v1)
# [arXiv 2024.07] Self-Similar Topological Fractals[[paper]](http://arxiv.org/pdf/2407.07643v1)
# [arXiv 2024.07] Machine learning of discrete field theories with guaranteed convergence and uncertainty quantification[[paper]](http://arxiv.org/pdf/2407.07642v1)
# [arXiv 2024.07] Tuning Vision-Language Models with Candidate Labels by Prompt Alignment[[paper]](http://arxiv.org/pdf/2407.07638v2)
# [arXiv 2024.07] MoVEInt: Mixture of Variational Experts for Learning Human-Robot Interactions from Demonstrations[[paper]](http://arxiv.org/pdf/2407.07636v1)
# [arXiv 2024.07] The stringy geometry of integral cohomology in mirror symmetry[[paper]](http://arxiv.org/pdf/2407.07635v1)
# [arXiv 2024.07] Reconstruction of Anosov flows from infinity[[paper]](http://arxiv.org/pdf/2407.07634v1)
# [arXiv 2024.07] Few-Shot Domain Adaptive Object Detection for Microscopic Images[[paper]](http://arxiv.org/pdf/2407.07633v1)
# [arXiv 2024.07] The role of green ammonia in meeting challenges towards a sustainable development in China[[paper]](http://arxiv.org/pdf/2407.07632v1)
# [arXiv 2024.07] Pessimism Meets Risk: Risk-Sensitive Offline Reinforcement Learning[[paper]](http://arxiv.org/pdf/2407.07631v1)
# [arXiv 2024.07] A Review of the Challenges with Massive Web-mined Corpora Used in Large Language Models Pre-Training[[paper]](http://arxiv.org/pdf/2407.07630v1)
# [arXiv 2024.07] Nonlinear Langevin functionals for a driven probe[[paper]](http://arxiv.org/pdf/2407.07628v1)
# [arXiv 2024.07] Synthetic to Authentic: Transferring Realism to 3D Face Renderings for Boosting Face Recognition[[paper]](http://arxiv.org/pdf/2407.07627v1)
# [arXiv 2024.07] Fusion of atomic W-like states in cavity QED systems[[paper]](http://arxiv.org/pdf/2407.07626v1)
# [arXiv 2024.07] Cones of Noether-Lefschetz divisors and moduli spaces of hyperkähler manifolds[[paper]](http://arxiv.org/pdf/2407.07622v1)
# [arXiv 2024.07] Cosserat Rods for Modeling Tendon-Driven Robotic Catheter Systems[[paper]](http://arxiv.org/pdf/2407.07618v1)
# [arXiv 2024.07] Psycho-linguistic Experiment on Universal Semantic Components of Verbal Humor: System Description and Annotation[[paper]](http://arxiv.org/pdf/2407.07617v1)
# [arXiv 2024.07] Satellite Image Time Series Semantic Change Detection: Novel Architecture and Analysis of Domain Shift[[paper]](http://arxiv.org/pdf/2407.07616v1)
# [arXiv 2024.07] Finite Control Set Model Predictive Control with Limit Cycle Stability Guarantees[[paper]](http://arxiv.org/pdf/2407.07615v1)
# [arXiv 2024.07] MARS: Mixture of Auto-Regressive Models for Fine-grained Text-to-image Synthesis[[paper]](http://arxiv.org/pdf/2407.07614v2)
# [arXiv 2024.07] Teaching Transformers Causal Reasoning through Axiomatic Training[[paper]](http://arxiv.org/pdf/2407.07612v1)
# [arXiv 2024.07] Physics-Informed Geometric Operators to Support Surrogate, Dimension Reduction and Generative Models for Engineering Design[[paper]](http://arxiv.org/pdf/2407.07611v1)
# [arXiv 2024.07] ALMA-IMF XII: Point-process mapping of 15 massive protoclusters[[paper]](http://arxiv.org/pdf/2407.07610v1)
# [arXiv 2024.07] Collective Effects in Breath Figures[[paper]](http://arxiv.org/pdf/2407.07608v1)
# [arXiv 2024.07] The Computational Learning of Construction Grammars: State of the Art and Prospective Roadmap[[paper]](http://arxiv.org/pdf/2407.07606v1)
# [arXiv 2024.07] Early Explorations of Lightweight Models for Wound Segmentation on Mobile Devices[[paper]](http://arxiv.org/pdf/2407.07605v2)
# [arXiv 2024.07] H-FCBFormer Hierarchical Fully Convolutional Branch Transformer for Occlusal Contact Segmentation with Articulating Paper[[paper]](http://arxiv.org/pdf/2407.07604v1)
# [arXiv 2024.07] iiANET: Inception Inspired Attention Hybrid Network for efficient Long-Range Dependency[[paper]](http://arxiv.org/pdf/2407.07603v1)
# [arXiv 2024.07] Ferromagnetic CrBr$_3$-Induced Graphene Spintronics[[paper]](http://arxiv.org/pdf/2407.07602v1)
# [arXiv 2024.07] Stability Analysis of Cantilever-like Structures with Applications to Soft Robotic Arms[[paper]](http://arxiv.org/pdf/2407.07601v1)
# [arXiv 2024.07] Can social media shape the security of next-generation connected vehicles?[[paper]](http://arxiv.org/pdf/2407.07599v1)
# [arXiv 2024.07] Targeted Augmented Data for Audio Deepfake Detection[[paper]](http://arxiv.org/pdf/2407.07598v1)
# [arXiv 2024.07] Scaling Law in Neural Data: Non-Invasive Speech Decoding with 175 Hours of EEG Data[[paper]](http://arxiv.org/pdf/2407.07595v1)
# [arXiv 2024.07] Observation of non-Abelian band topology without time-reversal symmetry[[paper]](http://arxiv.org/pdf/2407.07593v1)
# [arXiv 2024.07] MSC-LIO: An MSCKF-Based LiDAR-Inertial Odometry with Same-Plane-Point Tracking[[paper]](http://arxiv.org/pdf/2407.07589v1)
# [arXiv 2024.07] A photo-$z$ cautionary tale: Redshift confirmation of COSBO-7 at $z=2.625$[[paper]](http://arxiv.org/pdf/2407.07585v1)
# [arXiv 2024.07] Extended gamma-ray emission from particle escape in pulsar wind nebulae -- Application to HESS J1809-193 and HESS J1825-137[[paper]](http://arxiv.org/pdf/2407.07583v1)
# [arXiv 2024.07] InstructLayout: Instruction-Driven 2D and 3D Layout Synthesis with Semantic Graph Prior[[paper]](http://arxiv.org/pdf/2407.07580v2)
# [arXiv 2024.07] IDA-VLM: Towards Movie Understanding via ID-Aware Large Vision-Language Model[[paper]](http://arxiv.org/pdf/2407.07577v1)
# [arXiv 2024.07] On boundary conditions for linearised Einstein's equations[[paper]](http://arxiv.org/pdf/2407.07576v1)
# [arXiv 2024.07] Resource Allocation for Twin Maintenance and Computing Task Processing in Digital Twin Vehicular Edge Computing Network[[paper]](http://arxiv.org/pdf/2407.07575v1)
# [arXiv 2024.07] The nearest neutral gas phase to Supermassive Black Holes. A massive neutral-atom/molecule-rich Broad Line Region in AGNs[[paper]](http://arxiv.org/pdf/2407.07574v1)
# [arXiv 2024.07] Impact of dendritic non-linearities on the computational capabilities of neurons[[paper]](http://arxiv.org/pdf/2407.07572v1)
# [arXiv 2024.07] Completeness of Finitely Weighted Kleene Algebra With Tests[[paper]](http://arxiv.org/pdf/2407.07570v1)
# [arXiv 2024.07] Decomposition of multilayer superconductivity with interlayer pairing[[paper]](http://arxiv.org/pdf/2407.07569v1)
# [arXiv 2024.07] Birational maps, PBW degenerate flags and poset polytopes[[paper]](http://arxiv.org/pdf/2407.07568v1)
# [arXiv 2024.07] HebDB: a Weakly Supervised Dataset for Hebrew Speech Processing[[paper]](http://arxiv.org/pdf/2407.07566v1)
# [arXiv 2024.07] On Leakage of Code Generation Evaluation Datasets[[paper]](http://arxiv.org/pdf/2407.07565v2)
# [arXiv 2024.07] Trainable Highly-expressive Activation Functions[[paper]](http://arxiv.org/pdf/2407.07564v2)
# [arXiv 2024.07] FLAIR: Feeding via Long-horizon AcquIsition of Realistic dishes[[paper]](http://arxiv.org/pdf/2407.07561v1)
# [arXiv 2024.07] Instrumentation and Analysis of Native ML Pipelines via Logical Query Plans[[paper]](http://arxiv.org/pdf/2407.07560v1)
# [arXiv 2024.07] Impact of atomic initial conditions on nonclassicality of the light in the ladder-type three-level Jaynes-Cummings model[[paper]](http://arxiv.org/pdf/2407.07558v1)
# [arXiv 2024.07] Federated Foundation Model for Cardiac CT Imaging[[paper]](http://arxiv.org/pdf/2407.07557v1)
# [arXiv 2024.07] Conformal bootstrap and Mirror symmetry of states in Gepner models[[paper]](http://arxiv.org/pdf/2407.07555v1)
# [arXiv 2024.07] Dispersal-induced growth or decay in a time-periodic environment[[paper]](http://arxiv.org/pdf/2407.07553v1)
# [arXiv 2024.07] Attojoule superconducting thermal logic and memories[[paper]](http://arxiv.org/pdf/2407.07552v1)
# [arXiv 2024.07] Arabic Automatic Story Generation with Large Language Models[[paper]](http://arxiv.org/pdf/2407.07551v1)
# [arXiv 2024.07] Evaluating the method reproducibility of deep learning models in the biodiversity domain[[paper]](http://arxiv.org/pdf/2407.07550v1)
# [arXiv 2024.07] Lipschitz regularity for solutions to an orthotropic $q$-Laplacian-type equation in the Heisenberg group[[paper]](http://arxiv.org/pdf/2407.07548v1)
# [arXiv 2024.07] Search for diphoton resonances in the 66 to 110 GeV mass range using $pp$ collisions at $\sqrt{s}=13$ TeV with the ATLAS detector[[paper]](http://arxiv.org/pdf/2407.07546v1)
# [arXiv 2024.07] Disentangling Masked Autoencoders for Unsupervised Domain Generalization[[paper]](http://arxiv.org/pdf/2407.07544v1)
# [arXiv 2024.07] Swiss DINO: Efficient and Versatile Vision Framework for On-device Personal Object Search[[paper]](http://arxiv.org/pdf/2407.07541v1)
# [arXiv 2024.07] Machine Unlearning for Medical Imaging[[paper]](http://arxiv.org/pdf/2407.07539v1)
# [arXiv 2024.07] An epidemical model with nonlocal spatial infections[[paper]](http://arxiv.org/pdf/2407.07538v1)
# [arXiv 2024.07] Signature flips in time-varying $Λ(t)$ cosmological models with observational data[[paper]](http://arxiv.org/pdf/2407.07535v1)
# [arXiv 2024.07] Neural Localizer Fields for Continuous 3D Human Pose and Shape Estimation[[paper]](http://arxiv.org/pdf/2407.07532v1)
# [arXiv 2024.07] Beyond Benchmarking: A New Paradigm for Evaluation and Assessment of Large Language Models[[paper]](http://arxiv.org/pdf/2407.07531v1)
# [arXiv 2024.07] How Aligned are Different Alignment Metrics?[[paper]](http://arxiv.org/pdf/2407.07530v1)
# [arXiv 2024.07] Kaluza-Klein Graviton Freeze-In and Big Bang Nucleosynthesis[[paper]](http://arxiv.org/pdf/2407.07529v1)
# [arXiv 2024.07] MLRS-PDS: A Meta-learning recommendation of dynamic ensemble selection pipelines[[paper]](http://arxiv.org/pdf/2407.07528v1)
# [arXiv 2024.07] Low temperature conductivity of BaFe$_{0.5}$Nb$_{0.5}$O$_3$ double perovskite structure ceramics[[paper]](http://arxiv.org/pdf/2407.07527v1)
# [arXiv 2024.07] SHERL: Synthesizing High Accuracy and Efficient Memory for Resource-Limited Transfer Learning[[paper]](http://arxiv.org/pdf/2407.07523v1)
# [arXiv 2024.07] CHILLI: A data context-aware perturbation method for XAI[[paper]](http://arxiv.org/pdf/2407.07521v1)
# [arXiv 2024.07] IRSAM: Advancing Segment Anything Model for Infrared Small Target Detection[[paper]](http://arxiv.org/pdf/2407.07520v1)
# [arXiv 2024.07] Bilinear optimal control for chemotaxis model: The case of two-sidedly degenerate diffusion with Volume-Filling Effect[[paper]](http://arxiv.org/pdf/2407.07519v1)
# [arXiv 2024.07] Multi-modal Crowd Counting via a Broker Modality[[paper]](http://arxiv.org/pdf/2407.07518v1)
# [arXiv 2024.07] Parameter Efficient Fine Tuning for Multi-scanner PET to PET Reconstruction[[paper]](http://arxiv.org/pdf/2407.07517v1)
# [arXiv 2024.07] HDKD: Hybrid Data-Efficient Knowledge Distillation Network for Medical Image Classification[[paper]](http://arxiv.org/pdf/2407.07516v1)
# [arXiv 2024.07] The deep oxygen abundance in Solar System Giant Planets, with a new derivation for Saturn[[paper]](http://arxiv.org/pdf/2407.07515v1)
# [arXiv 2024.07] Swin SMT: Global Sequential Modeling in 3D Medical Image Segmentation[[paper]](http://arxiv.org/pdf/2407.07514v1)
# [arXiv 2024.07] High-rate quantum digital signatures network with integrated silicon photonics[[paper]](http://arxiv.org/pdf/2407.07513v1)
# [arXiv 2024.07] A Systematic Mapping Study on Teaching of Security Concepts in Programming Courses[[paper]](http://arxiv.org/pdf/2407.07511v1)
# [arXiv 2024.07] Invisible Optical Adversarial Stripes on Traffic Sign against Autonomous Vehicles[[paper]](http://arxiv.org/pdf/2407.07510v1)
# [arXiv 2024.07] Generative AI for RF Sensing in IoT systems[[paper]](http://arxiv.org/pdf/2407.07506v1)
# [arXiv 2024.07] Resurgence of Lunar Volcanism: Role of Localized Radioactive Enrichment in a Numerical Model of Magmatism and Mantle Convection[[paper]](http://arxiv.org/pdf/2407.07505v1)
# [arXiv 2024.07] Pan-cancer Histopathology WSI Pre-training with Position-aware Masked Autoencoder[[paper]](http://arxiv.org/pdf/2407.07504v1)
# [arXiv 2024.07] Understanding the Semantic SQL Transducer[[paper]](http://arxiv.org/pdf/2407.07502v1)
# [arXiv 2024.07] Bucket Pre-training is All You Need[[paper]](http://arxiv.org/pdf/2407.07495v1)
# [arXiv 2024.07] Panoptic Segmentation of Galactic Structures in LSB Images[[paper]](http://arxiv.org/pdf/2407.07494v1)
# [arXiv 2024.07] Fine-Grained Classification for Poisonous Fungi Identification with Transfer Learning[[paper]](http://arxiv.org/pdf/2407.07492v1)
# [arXiv 2024.07] A generalization of Krein`s extension formalism for symmetric relations with deficiency index (1,1)[[paper]](http://arxiv.org/pdf/2407.07491v1)
# [arXiv 2024.07] FUNAvg: Federated Uncertainty Weighted Averaging for Datasets with Diverse Labels[[paper]](http://arxiv.org/pdf/2407.07488v1)
# [arXiv 2024.07] Review-LLM: Harnessing Large Language Models for Personalized Review Generation[[paper]](http://arxiv.org/pdf/2407.07487v1)
# [arXiv 2024.07] Zero-Shot Class Unlearning in CLIP with Synthetic Samples[[paper]](http://arxiv.org/pdf/2407.07485v1)
# [arXiv 2024.07] A Decade of Collectivity in Small Systems[[paper]](http://arxiv.org/pdf/2407.07484v1)
# [arXiv 2024.07] Rigorous Probabilistic Guarantees for Robust Counterfactual Explanations[[paper]](http://arxiv.org/pdf/2407.07482v1)
# [arXiv 2024.07] How to Make Cross Encoder a Good Teacher for Efficient Image-Text Retrieval?[[paper]](http://arxiv.org/pdf/2407.07479v1)
# [arXiv 2024.07] EA-VTR: Event-Aware Video-Text Retrieval[[paper]](http://arxiv.org/pdf/2407.07478v1)
# [arXiv 2024.07] A Transverse-Read-assisted Valid-Bit Collection to Accelerate Stochastic Conmputing MAC for Energy-Efficient in-RTM DNNs[[paper]](http://arxiv.org/pdf/2407.07476v1)
# [arXiv 2024.07] Closed-Form EGN Model with Comprehensive Raman Support[[paper]](http://arxiv.org/pdf/2407.07473v1)
# [arXiv 2024.07] Rectifier: Code Translation with Corrector via LLMs[[paper]](http://arxiv.org/pdf/2407.07472v1)
# [arXiv 2024.07] An implementable proximal-type method for computing critical points to minimization problems with a nonsmooth and nonconvex constraint[[paper]](http://arxiv.org/pdf/2407.07471v1)
# [arXiv 2024.07] Observation of Klein bottle quadrupole topological insulators in electric circuits[[paper]](http://arxiv.org/pdf/2407.07470v1)
# [arXiv 2024.07] Development of an automatic modification system for generated programs using ChatGPT[[paper]](http://arxiv.org/pdf/2407.07469v1)
# [arXiv 2024.07] Bayesian weighted time-lapse full-waveform inversion using a receiver-extension strategy[[paper]](http://arxiv.org/pdf/2407.07467v1)
# [arXiv 2024.07] Discovery of HCCCH2CCH in TMC-1 with the QUIJOTE line survey[[paper]](http://arxiv.org/pdf/2407.07466v1)
# [arXiv 2024.07] Exploring the Untouched Sweeps for Conflict-Aware 3D Segmentation Pretraining[[paper]](http://arxiv.org/pdf/2407.07465v1)
# [arXiv 2024.07] Video-to-Audio Generation with Hidden Alignment[[paper]](http://arxiv.org/pdf/2407.07464v1)
# [arXiv 2024.07] Buoyancy driven motion of non-coalescing inertial drops: microstructure modeling with nearest particle statistics[[paper]](http://arxiv.org/pdf/2407.07463v1)
# [arXiv 2024.07] MAN TruckScenes: A multimodal dataset for autonomous trucking in diverse conditions[[paper]](http://arxiv.org/pdf/2407.07462v1)
# [arXiv 2024.07] Drantal-NeRF: Diffusion-Based Restoration for Anti-aliasing Neural Radiance Field[[paper]](http://arxiv.org/pdf/2407.07461v1)
# [arXiv 2024.07] Machine Learning Assisted Design of mmWave Wireless Transceiver Circuits[[paper]](http://arxiv.org/pdf/2407.07458v1)
# [arXiv 2024.07] GLBench: A Comprehensive Benchmark for Graph with Large Language Models[[paper]](http://arxiv.org/pdf/2407.07457v2)
# [arXiv 2024.07] GothX: a generator of customizable, legitimate and malicious IoT network traffic[[paper]](http://arxiv.org/pdf/2407.07456v1)
# [arXiv 2024.07] CM-DQN: A Value-Based Deep Reinforcement Learning Model to Simulate Confirmation Bias[[paper]](http://arxiv.org/pdf/2407.07454v1)
# [arXiv 2024.07] Waveguide Superlattices with Artificial Gauge Field Towards Colorless and Crosstalkless Ultrahigh-Density Photonic Integration[[paper]](http://arxiv.org/pdf/2407.07453v1)
# [arXiv 2024.07] Using Low-Discrepancy Points for Data Compression in Machine Learning: An Experimental Comparison[[paper]](http://arxiv.org/pdf/2407.07450v1)
# [arXiv 2024.07] The Roles of Spatial Frequencies and Degrees-of-Freedom in Near-Field Communications[[paper]](http://arxiv.org/pdf/2407.07448v1)
# [arXiv 2024.07] Network inference from oscillatory signals based on circle map[[paper]](http://arxiv.org/pdf/2407.07445v1)
# [arXiv 2024.07] Secondary Structure-Guided Novel Protein Sequence Generation with Latent Graph Diffusion[[paper]](http://arxiv.org/pdf/2407.07443v1)
# [arXiv 2024.07] On the structure of $T$-$λ$-spherical completions of o-minimal fields[[paper]](http://arxiv.org/pdf/2407.07442v1)
# [arXiv 2024.07] HAFormer: Unleashing the Power of Hierarchy-Aware Features for Lightweight Semantic Segmentation[[paper]](http://arxiv.org/pdf/2407.07441v2)
# [arXiv 2024.07] One-sided Markov additive processes with lattice and non-lattice increments[[paper]](http://arxiv.org/pdf/2407.07440v1)
# [arXiv 2024.07] Hybridizing Target- and SHAP-encoded Features for Algorithm Selection in Mixed-variable Black-box Optimization[[paper]](http://arxiv.org/pdf/2407.07439v1)
# [arXiv 2024.07] Radiative symmetry breaking from the on-shell perspective[[paper]](http://arxiv.org/pdf/2407.07437v1)
# [arXiv 2024.07] Controllable Navigation Instruction Generation with Chain of Thought Prompting[[paper]](http://arxiv.org/pdf/2407.07433v1)
# [arXiv 2024.07] Spectral Bridges[[paper]](http://arxiv.org/pdf/2407.07430v1)
# [arXiv 2024.07] A Conceptual Framework for API Refactoring in Enterprise Application Architectures[[paper]](http://arxiv.org/pdf/2407.07428v1)
# [arXiv 2024.07] Unified Embedding Alignment for Open-Vocabulary Video Instance Segmentation[[paper]](http://arxiv.org/pdf/2407.07427v1)
# [arXiv 2024.07] Out-of-distribution generalisation in spoken language understanding[[paper]](http://arxiv.org/pdf/2407.07425v1)
# [arXiv 2024.07] Estimation of the lateral mis-registrations of the GRAVITY + adaptive optics system[[paper]](http://arxiv.org/pdf/2407.07423v1)
# [arXiv 2024.07] Question-Score Identity Detection (Q-SID): A Statistical Algorithm to Detect Collusion Groups with Error Quantification from Exam Question Scores[[paper]](http://arxiv.org/pdf/2407.07420v1)
# [arXiv 2024.07] Dynamics of asymmetrically deformed skyrmion driven by internal forces and strain force in a flower-shaped magnetic nanostructure[[paper]](http://arxiv.org/pdf/2407.07418v1)
# [arXiv 2024.07] High $γ$-ray escape time in 2003fg-like supernovae: A challenge to proposed models[[paper]](http://arxiv.org/pdf/2407.07417v1)
# [arXiv 2024.07] On examining the predictive capabilities of two variants of PINN in validating localised wave solutions in the generalized nonlinear Schrödinger equation[[paper]](http://arxiv.org/pdf/2407.07415v1)
# [arXiv 2024.07] KpopMT: Translation Dataset with Terminology for Kpop Fandom[[paper]](http://arxiv.org/pdf/2407.07413v1)
# [arXiv 2024.07] Pseudo-RIS: Distinctive Pseudo-supervision Generation for Referring Image Segmentation[[paper]](http://arxiv.org/pdf/2407.07412v1)
# [arXiv 2024.07] Parallel implementation of the Density Matrix Renormalization Group method achieving a quarter petaFLOPS performance on a single DGX-H100 GPU node[[paper]](http://arxiv.org/pdf/2407.07411v1)
# [arXiv 2024.07] Weakly-supervised Medical Image Segmentation with Gaze Annotations[[paper]](http://arxiv.org/pdf/2407.07406v1)
# [arXiv 2024.07] Inoculating solid-state homogeneous precipitation by impurity atoms through a spinodal decomposition like pathway[[paper]](http://arxiv.org/pdf/2407.07404v1)
# [arXiv 2024.07] A Survey of Attacks on Large Vision-Language Models: Resources, Advances, and Future Trends[[paper]](http://arxiv.org/pdf/2407.07403v1)
# [arXiv 2024.07] ActionVOS: Actions as Prompts for Video Object Segmentation[[paper]](http://arxiv.org/pdf/2407.07402v1)
# [arXiv 2024.07] On the size multipartite Ramsey numbers involving complete graphs[[paper]](http://arxiv.org/pdf/2407.07401v1)
# [arXiv 2024.07] Krylov fractality and complexity in generic random matrix ensembles[[paper]](http://arxiv.org/pdf/2407.07399v1)
# [arXiv 2024.07] MagicPool: Dealing with Magic State Distillation Failures on Large-Scale Fault-Tolerant Quantum Computer[[paper]](http://arxiv.org/pdf/2407.07394v1)
# [arXiv 2024.07] CHOP: Integrating ChatGPT into EFL Oral Presentation Practice[[paper]](http://arxiv.org/pdf/2407.07393v1)
# [arXiv 2024.07] Malicious Path Manipulations via Exploitation of Representation Vulnerabilities of Vision-Language Navigation Systems[[paper]](http://arxiv.org/pdf/2407.07392v1)
# [arXiv 2024.07] Hole Statistics of Equilibrium 2D and 3D Hard-Sphere Crystals[[paper]](http://arxiv.org/pdf/2407.07390v1)
# [arXiv 2024.07] Greit-HRNet: Grouped Lightweight High-Resolution Network for Human Pose Estimation[[paper]](http://arxiv.org/pdf/2407.07389v1)
# [arXiv 2024.07] Tail Bounds on the Runtime of Categorical Compact Genetic Algorithm[[paper]](http://arxiv.org/pdf/2407.07388v1)
# [arXiv 2024.07] Evidence for auroral influence on Jupiter's nitrogen and oxygen chemistry revealed by ALMA[[paper]](http://arxiv.org/pdf/2407.07385v1)
# [arXiv 2024.07] Worldline integration of photon amplitudes[[paper]](http://arxiv.org/pdf/2407.07383v1)
# [arXiv 2024.07] Deep(er) Reconstruction of Imaging Cherenkov Detectors with Swin Transformers and Normalizing Flow Models[[paper]](http://arxiv.org/pdf/2407.07376v1)
# [arXiv 2024.07] DuInNet: Dual-Modality Feature Interaction for Point Cloud Completion[[paper]](http://arxiv.org/pdf/2407.07374v1)
# [arXiv 2024.07] Automatic Extraction of Disease Risk Factors from Medical Publications[[paper]](http://arxiv.org/pdf/2407.07373v1)
# [arXiv 2024.07] Formulation and analysis of a DPG discretization for a simplified electrochemical model[[paper]](http://arxiv.org/pdf/2407.07371v1)
# [arXiv 2024.07] LokiLM: Technical Report[[paper]](http://arxiv.org/pdf/2407.07370v1)
# [arXiv 2024.07] Data-driven Bayesian State Estimation with Compressed Measurement of Model-free Process using Semi-supervised Learning[[paper]](http://arxiv.org/pdf/2407.07368v1)
# [arXiv 2024.07] Real-time system optimal traffic routing under uncertainties -- Can physics models boost reinforcement learning?[[paper]](http://arxiv.org/pdf/2407.07364v1)
# [arXiv 2024.07] Black hole spin estimation of XTE J2012+381 using simultaneous observations of Swift/XRT and NuSTAR[[paper]](http://arxiv.org/pdf/2407.07362v1)
# [arXiv 2024.07] Towards a text-based quantitative and explainable histopathology image analysis[[paper]](http://arxiv.org/pdf/2407.07360v1)
# [arXiv 2024.07] SGM-PINN: Sampling Graphical Models for Faster Training of Physics-Informed Neural Networks[[paper]](http://arxiv.org/pdf/2407.07358v1)
# [arXiv 2024.07] A deep graph model for the signed interaction prediction in biological network[[paper]](http://arxiv.org/pdf/2407.07357v1)
# [arXiv 2024.07] Video In-context Learning[[paper]](http://arxiv.org/pdf/2407.07356v1)
# [arXiv 2024.07] Asymmetric Fluid Flow in Helical Pipes Inspired by Shark Intestines[[paper]](http://arxiv.org/pdf/2407.07354v1)
# [arXiv 2024.07] Berry Phase and Topological Insights in a Qubit-Inspired Classical Two-Level Elastic Bit[[paper]](http://arxiv.org/pdf/2407.07353v1)
# [arXiv 2024.07] Unity in Diversity: Multi-expert Knowledge Confrontation and Collaboration for Generalizable Vehicle Re-identification[[paper]](http://arxiv.org/pdf/2407.07351v1)
# [arXiv 2024.07] Long-Term Fairness in Sequential Multi-Agent Selection with Positive Reinforcement[[paper]](http://arxiv.org/pdf/2407.07350v1)
# [arXiv 2024.07] Ferromagnetic polar metals via epitaxial strain: a case study of SrCoO$_3$[[paper]](http://arxiv.org/pdf/2407.07349v1)
# [arXiv 2024.07] MNeRV: A Multilayer Neural Representation for Videos[[paper]](http://arxiv.org/pdf/2407.07347v1)
# [arXiv 2024.07] INSIGHT: Universal Neural Simulator for Analog Circuits Harnessing Autoregressive Transformers[[paper]](http://arxiv.org/pdf/2407.07346v1)
# [arXiv 2024.07] Micro-Expression Recognition by Motion Feature Extraction based on Pre-training[[paper]](http://arxiv.org/pdf/2407.07345v1)
# [arXiv 2024.07] Electrically Tuning Quasi-Bound States in the Continuum with Hybrid Graphene-Silicon Metasurfaces[[paper]](http://arxiv.org/pdf/2407.07343v1)
# [arXiv 2024.07] Multilingual Blending: LLM Safety Alignment Evaluation with Language Mixture[[paper]](http://arxiv.org/pdf/2407.07342v1)
# [arXiv 2024.07] MixSumm: Topic-based Data Augmentation using LLMs for Low-resource Extractive Text Summarization[[paper]](http://arxiv.org/pdf/2407.07341v1)
# [arXiv 2024.07] FALFormer: Feature-aware Landmarks self-attention for Whole-slide Image Classification[[paper]](http://arxiv.org/pdf/2407.07340v2)
# [arXiv 2024.07] TDML -- A Trustworthy Distributed Machine Learning Framework[[paper]](http://arxiv.org/pdf/2407.07339v1)
# [arXiv 2024.07] Interpretable Differential Diagnosis with Dual-Inference Large Language Models[[paper]](http://arxiv.org/pdf/2407.07330v1)
# [arXiv 2024.07] Probability of Differentiation Reveals Brittleness of Homogeneity Bias in Large Language Models[[paper]](http://arxiv.org/pdf/2407.07329v1)
# [arXiv 2024.07] CATP: Context-Aware Trajectory Prediction with Competition Symbiosis[[paper]](http://arxiv.org/pdf/2407.07328v1)
# [arXiv 2024.07] Fuse, Reason and Verify: Geometry Problem Solving with Parsed Clauses from Diagram[[paper]](http://arxiv.org/pdf/2407.07327v1)
# [arXiv 2024.07] Convergence of persistence diagrams for discrete time stationary processes[[paper]](http://arxiv.org/pdf/2407.07326v1)
# [arXiv 2024.07] HiLight: Technical Report on the Motern AI Video Language Model[[paper]](http://arxiv.org/pdf/2407.07325v2)
# [arXiv 2024.07] Event-Aided Time-to-Collision Estimation for Autonomous Driving[[paper]](http://arxiv.org/pdf/2407.07324v1)
# [arXiv 2024.07] The Age-Dependent Vertical Actions of Young Stars in the Galaxy[[paper]](http://arxiv.org/pdf/2407.07323v1)
# [arXiv 2024.07] Integrating Human-Centric Approaches into Undergraduate Software Engineering Education: A Scoping Review and Curriculum Analysis in the Australian Context[[paper]](http://arxiv.org/pdf/2407.07322v1)
# [arXiv 2024.07] RAG vs. Long Context: Examining Frontier Large Language Models for Environmental Review Document Comprehension[[paper]](http://arxiv.org/pdf/2407.07321v1)
# [arXiv 2024.07] Flow-acoustic resonance in deep and inclined cavities[[paper]](http://arxiv.org/pdf/2407.07317v1)
# [arXiv 2024.07] CosmoCLIP: Generalizing Large Vision-Language Models for Astronomical Imaging[[paper]](http://arxiv.org/pdf/2407.07315v1)
# [arXiv 2024.07] ESM+: Modern Insights into Perspective on Text-to-SQL Evaluation in the Age of Large Language Models[[paper]](http://arxiv.org/pdf/2407.07313v1)
# [arXiv 2024.07] Hybrid Synchronization with Continuous Varying Exponent in Decentralized Power Grid[[paper]](http://arxiv.org/pdf/2407.07312v1)
# [arXiv 2024.07] ViTime: A Visual Intelligence-Based Foundation Model for Time Series Forecasting[[paper]](http://arxiv.org/pdf/2407.07311v1)
# [arXiv 2024.07] Coordinated JWST Imaging of Three Distance Indicators in a SN Host Galaxy and an Estimate of the TRGB Color Dependence[[paper]](http://arxiv.org/pdf/2407.07309v1)
# [arXiv 2024.07] Dual-stage Hyperspectral Image Classification Model with Spectral Supertoken[[paper]](http://arxiv.org/pdf/2407.07307v1)
# [arXiv 2024.07] Electrical Impedance Tomography Based Closed-loop Tumor Treating Fields in Dynamic Lung Tumors[[paper]](http://arxiv.org/pdf/2407.07306v1)
# [arXiv 2024.07] Inference Performance Optimization for Large Language Models on CPUs[[paper]](http://arxiv.org/pdf/2407.07304v1)
# [arXiv 2024.07] Bimerons create bimerons: proliferation and aggregation induced by currents and magnetic fields[[paper]](http://arxiv.org/pdf/2407.07303v1)
# [arXiv 2024.07] Pairwise Distance Distillation for Unsupervised Real-World Image Super-Resolution[[paper]](http://arxiv.org/pdf/2407.07302v1)
# [arXiv 2024.07] From Principles to Rules: A Regulatory Approach for Frontier AI[[paper]](http://arxiv.org/pdf/2407.07300v1)
# [arXiv 2024.07] Large Language Model-Augmented Auto-Delineation of Treatment Target Volume in Radiation Therapy[[paper]](http://arxiv.org/pdf/2407.07296v1)
# [arXiv 2024.07] Deformation-Recovery Diffusion Model (DRDM): Instance Deformation for Image Manipulation and Synthesis[[paper]](http://arxiv.org/pdf/2407.07295v1)
# [arXiv 2024.07] Causal Discovery in Semi-Stationary Time Series[[paper]](http://arxiv.org/pdf/2407.07291v1)
# [arXiv 2024.07] Causal Discovery-Driven Change Point Detection in Time Series[[paper]](http://arxiv.org/pdf/2407.07290v1)
# [arXiv 2024.07] Deformable Feature Alignment and Refinement for Moving Infrared Dim-small Target Detection[[paper]](http://arxiv.org/pdf/2407.07289v1)
# [arXiv 2024.07] Structural Design Through Reinforcement Learning[[paper]](http://arxiv.org/pdf/2407.07288v1)
# [arXiv 2024.07] Natural measures and statistical properties of non-statistical maps with multiple neutral fixed points[[paper]](http://arxiv.org/pdf/2407.07286v1)
# [arXiv 2024.07] MIGS: Multi-Identity Gaussian Splatting via Tensor Decomposition[[paper]](http://arxiv.org/pdf/2407.07284v1)
# [arXiv 2024.07] Asymptotic locations of bounded and unbounded eigenvalues of sample correlation matrices of certain factor models -- application to a components retention rule[[paper]](http://arxiv.org/pdf/2407.07282v1)
# [arXiv 2024.07] Decentralized Droop-based Finite-Control-Set Model Predictive Control of Inverter-based Resources in Islanded AC Microgrid[[paper]](http://arxiv.org/pdf/2407.07281v1)
# [arXiv 2024.07] Towards a theory of learning dynamics in deep state space models[[paper]](http://arxiv.org/pdf/2407.07279v1)
# [arXiv 2024.07] Lifestyle-Informed Personalized Blood Biomarker Prediction via Novel Representation Learning[[paper]](http://arxiv.org/pdf/2407.07277v1)
# [arXiv 2024.07] Exploring Camera Encoder Designs for Autonomous Driving Perception[[paper]](http://arxiv.org/pdf/2407.07276v1)
# [arXiv 2024.07] Remastering Divide and Remaster: A Cinematic Audio Source Separation Dataset with Multilingual Support[[paper]](http://arxiv.org/pdf/2407.07275v1)
# [arXiv 2024.07] An interdisciplinary data-science approach to managing natural hazards risk[[paper]](http://arxiv.org/pdf/2407.07270v1)
# [arXiv 2024.07] Model-based Maintenance and Evolution with GenAI: A Look into the Future[[paper]](http://arxiv.org/pdf/2407.07269v1)
# [arXiv 2024.07] Dataset Quantization with Active Learning based Adaptive Sampling[[paper]](http://arxiv.org/pdf/2407.07268v1)
# ...
# [arXiv 2024.07] Protein Design by Integrating Machine Learning with Quantum Annealing and Quantum-inspired Optimization[[paper]](http://arxiv.org/pdf/2407.07177v1)
# [arXiv 2024.07] Scaling Up Personalized Aesthetic Assessment via Task Vector Customization[[paper]](http://arxiv.org/pdf/2407.07176v1)
# [arXiv 2024.07] CamFreeDiff: Camera-free Image to Panorama Generation with Diffusion Model[[paper]](http://arxiv.org/pdf/2407.07174v1)
# [arXiv 2024.07] ItTakesTwo: Leveraging Peer Representations for Semi-supervised LiDAR Semantic Segmentation[[paper]](http://arxiv.org/pdf/2407.07171v1)
# [arXiv 2024.07] Limit theorems for Non-Markovian rumor models[[paper]](http://arxiv.org/pdf/2407.07170v1)
# [arXiv 2024.07] Redshifts of candidate host galaxies of four fast X-ray transients using VLT/MUSE[[paper]](http://arxiv.org/pdf/2407.07167v1)
# [arXiv 2024.07] The YMCA (Yes, Magellanic Clouds Again) survey: probing the outer regions of the Magellanic system with VST[[paper]](http://arxiv.org/pdf/2407.07163v1)
# [arXiv 2024.07] Exploring a primordial solution for early black holes detected with the JWST[[paper]](http://arxiv.org/pdf/2407.07162v1)
# [arXiv 2024.07] Reducing Complex Phases and other Subtleties of CP Violation[[paper]](http://arxiv.org/pdf/2407.07158v1)
# [arXiv 2024.07] Cyclic solid-state quantum battery: Thermodynamic characterization and quantum hardware simulation[[paper]](http://arxiv.org/pdf/2407.07157v1)
# [arXiv 2024.07] Evidence for large baryonic feedback at low and intermediate redshifts from kinematic Sunyaev-Zel'dovich observations with ACT and DESI photometric galaxies[[paper]](http://arxiv.org/pdf/2407.07152v1)
# [arXiv 2024.07] Hierarchical Three-Body Problem at High Eccentricities = Simple Pendulum[[paper]](http://arxiv.org/pdf/2407.07154v1)
# [arXiv 2024.07] Bathing in a sea of candidate quantum spin liquids: From the gapless ruby to the gapped maple-leaf lattice[[paper]](http://arxiv.org/pdf/2407.07145v1)
# [arXiv 2024.07] Constraints on FRB emission in the aftermath of GRBs[[paper]](http://arxiv.org/pdf/2407.07146v1)
# [arXiv 2024.07] Hunting 3d $\mathcal{N}=1$ SQED in the $ε$-expansion[[paper]](http://arxiv.org/pdf/2407.07148v1)
# [arXiv 2024.07] Iron Snails: non-equilibrium dynamics and spiral abundance patterns[[paper]](http://arxiv.org/pdf/2407.07149v1)
# [arXiv 2024.07] LANSCE-mQ: Dedicated search for milli/fractionally charged particles at LANL[[paper]](http://arxiv.org/pdf/2407.07142v1)
# [arXiv 2024.07] QCD Axion Dark Matter in String Theory: Haloscopes and Helioscopes as Probes of the Landscape[[paper]](http://arxiv.org/pdf/2407.07143v1)
# [arXiv 2024.07] AnyTaskTune: Advanced Domain-Specific Solutions through Task-Fine-Tuning[[paper]](http://arxiv.org/pdf/2407.07094v1)
# [arXiv 2024.07] FBI-LLM: Scaling Up Fully Binarized LLMs from Scratch via Autoregressive Distillation[[paper]](http://arxiv.org/pdf/2407.07093v1)
# [arXiv 2024.07] General Relativistic effects and the NIR variability of Sgr A* II: A systematic approach to temporal asymmetry[[paper]](http://arxiv.org/pdf/2407.07091v1)
# [arXiv 2024.07] 3D Gaussian Ray Tracing: Fast Tracing of Particle Scenes[[paper]](http://arxiv.org/pdf/2407.07090v2)
# [arXiv 2024.07] Fine-Tuning Linear Layers Only Is a Simple yet Effective Way for Task Arithmetic[[paper]](http://arxiv.org/pdf/2407.07089v1)
# [arXiv 2024.07] Safe and Reliable Training of Learning-Based Aerospace Controllers[[paper]](http://arxiv.org/pdf/2407.07088v1)
# [arXiv 2024.07] CopyBench: Measuring Literal and Non-Literal Reproduction of Copyright-Protected Text in Language Model Generation[[paper]](http://arxiv.org/pdf/2407.07087v1)
# [arXiv 2024.07] Hypothetical Minds: Scaffolding Theory of Mind for Multi-Agent Tasks with Large Language Models[[paper]](http://arxiv.org/pdf/2407.07086v1)
# [arXiv 2024.07] Pathways to Interstellar Amides via Carbamoyl (NH2CO) Isomers by Radical-Neutral Reactions on Ice Grain Mantles[[paper]](http://arxiv.org/pdf/2407.07081v1)
# [arXiv 2024.07] Adapting LLMs to Hebrew: Unveiling DictaLM 2.0 with Enhanced Vocabulary and Instruction Capabilities[[paper]](http://arxiv.org/pdf/2407.07080v1)
# [arXiv 2024.07] MoSt-DSA: Modeling Motion and Structural Interactions for Direct Multi-Frame Interpolation in DSA Images[[paper]](http://arxiv.org/pdf/2407.07078v1)
# [arXiv 2024.07] ConceptExpress: Harnessing Diffusion Models for Single-image Unsupervised Concept Extraction[[paper]](http://arxiv.org/pdf/2407.07077v1)
# [arXiv 2024.07] MADE-for-ASD: A Multi-Atlas Deep Ensemble Network for Diagnosing Autism Spectrum Disorder[[paper]](http://arxiv.org/pdf/2407.07076v1)
# [arXiv 2024.07] Enhanced $ψ^{\prime}$ yield and $ψ^{\prime}/(J/ψ)$ yield ratio as a possible signature of QGP formation in high multiplicity $p+p$ collisions[[paper]](http://arxiv.org/pdf/2407.07073v1)
# [arXiv 2024.07] Lookback Lens: Detecting and Mitigating Contextual Hallucinations in Large Language Models Using Only Attention Maps[[paper]](http://arxiv.org/pdf/2407.07071v1)
# [arXiv 2024.07] Chance-Constrained Energy Storage Pricing for Social Welfare Maximization[[paper]](http://arxiv.org/pdf/2407.07068v1)
# [arXiv 2024.07] Aggregate Bayesian Causal Forests: The ABCs of Flexible Causal Inference for Hierarchically Structured Data[[paper]](http://arxiv.org/pdf/2407.07067v1)
# [arXiv 2024.07] Explainable Hyperdimensional Computing for Balancing Privacy and Transparency in Additive Manufacturing Monitoring[[paper]](http://arxiv.org/pdf/2407.07066v2)
# [arXiv 2024.07] Prompting Techniques for Secure Code Generation: A Systematic Investigation[[paper]](http://arxiv.org/pdf/2407.07064v1)
# [arXiv 2024.07] Internet of Agents: Weaving a Web of Heterogeneous Agents for Collaborative Intelligence[[paper]](http://arxiv.org/pdf/2407.07061v2)
# [arXiv 2024.07] Differentiable Optimization of Similarity Scores Between Models and Brains[[paper]](http://arxiv.org/pdf/2407.07059v1)
# [arXiv 2024.07] Multicell-Fold: geometric learning in folding multicellular life[[paper]](http://arxiv.org/pdf/2407.07055v1)
# [arXiv 2024.07] Multimodal Self-Instruct: Synthetic Abstract Image and Visual Reasoning Instruction Using Language Model[[paper]](http://arxiv.org/pdf/2407.07053v2)
# [arXiv 2024.07] Latent Space Imaging[[paper]](http://arxiv.org/pdf/2407.07052v1)
# [arXiv 2024.07] Support and Scandals in GameFi dApps: A Network Analysis of The Sandbox Transactions[[paper]](http://arxiv.org/pdf/2407.07138v1)
# [arXiv 2024.07] Quasiperiodicity protects quantized transport in disordered systems without gaps[[paper]](http://arxiv.org/pdf/2407.07049v1)
# [arXiv 2024.07] Ba Enrichment in Gaia MS+WD Binaries: Tracing $s$-Process Element Production[[paper]](http://arxiv.org/pdf/2407.07048v1)
# [arXiv 2024.07] CorMulT: A Semi-supervised Modality Correlation-aware Multimodal Transformer for Sentiment Analysis[[paper]](http://arxiv.org/pdf/2407.07046v1)
# [arXiv 2024.07] Simple and Interpretable Probabilistic Classifiers for Knowledge Graphs[[paper]](http://arxiv.org/pdf/2407.07045v1)
# [arXiv 2024.07] Fuzzy Gravity: Four-Dimensional Gravity on a Covariant Noncommutative Space and Unification with Internal Interactions[[paper]](http://arxiv.org/pdf/2407.07044v1)
# [arXiv 2024.07] ProtoSAM -- One Shot Medical Image Segmentation With Foundational Models[[paper]](http://arxiv.org/pdf/2407.07042v1)
# [arXiv 2024.07] Decoding Climate Disagreement: A Graph Neural Network-Based Approach to Understanding Social Media Dynamics[[paper]](http://arxiv.org/pdf/2407.07038v1)
# [arXiv 2024.07] Vision-and-Language Navigation Today and Tomorrow: A Survey in the Era of Foundation Models[[paper]](http://arxiv.org/pdf/2407.07035v1)
# [arXiv 2024.07] Free Fermionic Constructions of Heterotic Strings[[paper]](http://arxiv.org/pdf/2407.07034v1)
# [arXiv 2024.07] Trajectory Data Mining and Trip Travel Time Prediction on Specific Roads[[paper]](http://arxiv.org/pdf/2407.07030v1)
# [arXiv 2024.07] Resolving Sentiment Discrepancy for Multimodal Sentiment Detection via Semantics Completion and Decomposition[[paper]](http://arxiv.org/pdf/2407.07026v1)
# [arXiv 2024.07] Exploring Scalability of Self-Training for Open-Vocabulary Temporal Action Localization[[paper]](http://arxiv.org/pdf/2407.07024v1)
# [arXiv 2024.07] Treatment of the strongly correlated topological superconductors through the $su(2|1)$ path-integral technique[[paper]](http://arxiv.org/pdf/2407.07022v2)
# [arXiv 2024.07] Less is More: Efficient Brain-Inspired Learning for Autonomous Driving Trajectory Prediction[[paper]](http://arxiv.org/pdf/2407.07020v1)
# [arXiv 2024.07] Using Large Language Models for Generating Smart Contracts for Health Insurance from Textual Policies[[paper]](http://arxiv.org/pdf/2407.07019v1)
# [arXiv 2024.07] End-To-End Causal Effect Estimation from Unstructured Natural Language Data[[paper]](http://arxiv.org/pdf/2407.07018v1)
# [arXiv 2024.07] Is Large Language Model All You Need to Predict the Synthesizability and Precursors of Crystal Structures?[[paper]](http://arxiv.org/pdf/2407.07016v1)
# [arXiv 2024.07] A Framework for Multimodal Medical Image Interaction[[paper]](http://arxiv.org/pdf/2407.07015v1)
# [arXiv 2024.07] An Attempt to Devise a Pairwise Ising-Type Maximum Entropy Model Integrated Cost Function for Optimizing SNN Deployment[[paper]](http://arxiv.org/pdf/2407.07014v2)
# [arXiv 2024.07] Bow-shock structure of Sgr B molecular-cloud complex in the Galactic Centre inferred from 3D CO-line kinematics[[paper]](http://arxiv.org/pdf/2407.07013v1)
# [arXiv 2024.07] Approach to stationarity for the KPZ fixed point with boundaries[[paper]](http://arxiv.org/pdf/2407.07012v1)
# [arXiv 2024.07] Induction Heads as an Essential Mechanism for Pattern Matching in In-context Learning[[paper]](http://arxiv.org/pdf/2407.07011v1)
# [arXiv 2024.07] Regular out of the singular: exacts results on top of a curvature singularity[[paper]](http://arxiv.org/pdf/2407.07010v1)
# [arXiv 2024.07] Non-Hermitian $\mathbb{Z}_4$ skin effect protected by glide symmetry[[paper]](http://arxiv.org/pdf/2407.07136v1)
# [arXiv 2024.07] Explainable AI for Enhancing Efficiency of DL-based Channel Estimation[[paper]](http://arxiv.org/pdf/2407.07009v1)
# [arXiv 2024.07] Generative models of astrophysical fields with scattering transforms on the sphere[[paper]](http://arxiv.org/pdf/2407.07007v1)
# [arXiv 2024.07] A PSPACE Algorithm for Almost-Sure Rabin Objectives in Multi-Environment MDPs[[paper]](http://arxiv.org/pdf/2407.07006v1)
# [arXiv 2024.07] Empirical analysis of Biding Precedent efficiency in the Brazilian Supreme Court via Similar Case Retrieval[[paper]](http://arxiv.org/pdf/2407.07004v1)
# [arXiv 2024.07] A local infall from a cosmographic analysis of Pantheon+[[paper]](http://arxiv.org/pdf/2407.07002v1)
# [arXiv 2024.07] Metron: Holistic Performance Evaluation Framework for LLM Inference Systems[[paper]](http://arxiv.org/pdf/2407.07000v1)
# [arXiv 2024.07] Robust Neural Information Retrieval: An Adversarial and Out-of-distribution Perspective[[paper]](http://arxiv.org/pdf/2407.06992v1)
# [arXiv 2024.07] Segment-Based Interactive Machine Translation for Pre-trained Models[[paper]](http://arxiv.org/pdf/2407.06990v1)
# [arXiv 2024.07] Higher order weak values for paths in nested Mach-Zender interferometers[[paper]](http://arxiv.org/pdf/2407.06989v1)
# [arXiv 2024.07] Limiting Over-Smoothing and Over-Squashing of Graph Message Passing by Deep Scattering Transforms[[paper]](http://arxiv.org/pdf/2407.06988v1)
# [arXiv 2024.07] Stochastic excitation of waves in magnetic stars -- I. Scaling laws for the modes amplitudes[[paper]](http://arxiv.org/pdf/2407.06987v1)
# [arXiv 2024.07] PEER: Expertizing Domain-Specific Tasks with a Multi-Agent Framework and Tuning Methods[[paper]](http://arxiv.org/pdf/2407.06985v2)
# [arXiv 2024.07] Can virtual staining for high-throughput screening generalize?[[paper]](http://arxiv.org/pdf/2407.06979v1)
# [arXiv 2024.07] Investigation of sources affecting longitudinal particle distribution in heavy-ion collisions using spectators[[paper]](http://arxiv.org/pdf/2407.06977v1)
# [arXiv 2024.07] Advancing Manuscript Metadata: Work in Progress at the Jagiellonian University[[paper]](http://arxiv.org/pdf/2407.06976v1)
# [arXiv 2024.07] Effect estimation in the presence of a misclassified binary mediator[[paper]](http://arxiv.org/pdf/2407.06970v1)
# [arXiv 2024.07] An automata-based approach for synchronizable mailbox communication[[paper]](http://arxiv.org/pdf/2407.06968v2)
# [arXiv 2024.07] Improving Out-of-Distribution Detection by Combining Existing Post-hoc Methods[[paper]](http://arxiv.org/pdf/2407.07135v1)
# [arXiv 2024.07] Parameter-Efficient and Memory-Efficient Tuning for Vision Transformer: A Disentangled Approach[[paper]](http://arxiv.org/pdf/2407.06964v1)
# [arXiv 2024.07] Combined Fit of Spectrum and Composition for FR0 Radio Galaxy Emitted Ultra-High-Energy Cosmic Rays with Resulting Secondary Photons and Neutrinos[[paper]](http://arxiv.org/pdf/2407.06961v1)
# [arXiv 2024.07] Listen and Speak Fairly: A Study on Semantic Gender Bias in Speech Integrated Large Language Models[[paper]](http://arxiv.org/pdf/2407.06957v1)
# [arXiv 2024.07] Domain theory in univalent foundations II: Continuous and algebraic domains[[paper]](http://arxiv.org/pdf/2407.06956v2)
# [arXiv 2024.07] ICLGuard: Controlling In-Context Learning Behavior for Applicability Authorization[[paper]](http://arxiv.org/pdf/2407.06955v1)
# [arXiv 2024.07] Simulations of Mpemba Effect in WATER, Lennard-Jones and Ising Models: Metastability vs Critical Fluctuations[[paper]](http://arxiv.org/pdf/2407.06954v1)
# [arXiv 2024.07] SP-Chain: Boosting Intra-Shard and Cross-Shard Security and Performance in Blockchain Sharding[[paper]](http://arxiv.org/pdf/2407.06953v1)
# [arXiv 2024.07] Domain theory in univalent foundations I: Directed complete posets and Scott's $D_\infty$[[paper]](http://arxiv.org/pdf/2407.06952v2)
# [arXiv 2024.07] RoboCAS: A Benchmark for Robotic Manipulation in Complex Object Arrangement Scenarios[[paper]](http://arxiv.org/pdf/2407.06951v1)
# [arXiv 2024.07] Spanish TrOCR: Leveraging Transfer Learning for Language Adaptation[[paper]](http://arxiv.org/pdf/2407.06950v1)
# [arXiv 2024.07] Audio-Language Datasets of Scenes and Events: A Survey[[paper]](http://arxiv.org/pdf/2407.06947v1)
# [arXiv 2024.07] Self-Recognition in Language Models[[paper]](http://arxiv.org/pdf/2407.06946v1)
# [arXiv 2024.07] Additive energies of subsets of discrete cubes[[paper]](http://arxiv.org/pdf/2407.06944v1)
# [arXiv 2024.07] A Starter's Kit for Concentric Tube Robots[[paper]](http://arxiv.org/pdf/2407.06943v1)
# [arXiv 2024.07] An Improved Two-Step Attack on CRYSTALS-Kyber[[paper]](http://arxiv.org/pdf/2407.06942v1)
# [arXiv 2024.07] Raply: A profanity-mitigated rap generator[[paper]](http://arxiv.org/pdf/2407.06941v1)
# [arXiv 2024.07] Scott Complexity of Reduced Abelian $p$-Groups[[paper]](http://arxiv.org/pdf/2407.06940v1)
# [arXiv 2024.07] RodinHD: High-Fidelity 3D Avatar Generation with Diffusion Models[[paper]](http://arxiv.org/pdf/2407.06938v2)
# [arXiv 2024.07] HumanRefiner: Benchmarking Abnormal Human Generation and Refining with Coarse-to-fine Pose-Reversible Guidance[[paper]](http://arxiv.org/pdf/2407.06937v1)
# [arXiv 2024.07] NEMESISPY: A Python package for simulating and retrieving exoplanetary spectra[[paper]](http://arxiv.org/pdf/2407.06932v1)
# [arXiv 2024.07] A Unified Approach to Multi-task Legged Navigation: Temporal Logic Meets Reinforcement Learning[[paper]](http://arxiv.org/pdf/2407.06931v1)
# [arXiv 2024.07] Integrating Ontology Design with the CRISP-DM in the context of Cyber-Physical Systems Maintenance[[paper]](http://arxiv.org/pdf/2407.06930v1)
# [arXiv 2024.07] Shifts in Brain Dynamics and Drivers of Consciousness State Transitions[[paper]](http://arxiv.org/pdf/2407.06928v1)
# [arXiv 2024.07] Emerging Majorana bound states in superconducting Haldane nanoribbons[[paper]](http://arxiv.org/pdf/2407.06925v1)
# [arXiv 2024.07] foetus -- Termination Checker for Simple Functional Programs[[paper]](http://arxiv.org/pdf/2407.06924v1)
# [arXiv 2024.07] A survey on isothermal and isentropic Baer-Nunziato-type models[[paper]](http://arxiv.org/pdf/2407.06919v1)

# %%
import arxiv

# Construct the default API client.
client = arxiv.Client()

# Search for the 10 most recent articles matching the keyword "quantum."
search = arxiv.Search(
  query = "Large Language Models",
  max_results = 10,
  sort_by = arxiv.SortCriterion.SubmittedDate
)

results = client.results(search)

# `results` is a generator; you can iterate over its elements one by one...
for r in client.results(search):
  print(r.title)
# ...or exhaust it into a list. Careful: this is slow for large results sets.
all_results = list(results)
print([r.title for r in all_results])

# For advanced query syntax documentation, see the arXiv API User Manual:
# https://arxiv.org/help/api/user-manual#query_details
search = arxiv.Search(query = "au:del_maestro AND ti:checkerboard")
first_result = next(client.results(search))
print(first_result)

# Search for the paper with ID "1605.08386v1"
search_by_id = arxiv.Search(id_list=["1605.08386v1"])
# Reuse client to fetch the paper, then print its title.
first_result = next(client.results(search))
print(first_result.title)

# %%
import requests
import json

def fetch_and_categorize_papers(venue_id):
    url = f"https://api2.openreview.net/notes?content.venueid={venue_id}"
    response = requests.get(url)
    data = response.json()
    
    # Initialize dictionaries to hold categorized papers
    papers_by_type = {'Oral': [], 'Spotlight': [], 'Poster': []}
    
    # Iterate over all papers and categorize them
    if 'notes' in data:
        for note in data['notes']:
            venue_info = note['content'].get('venue', {})
            if 'value' in venue_info:
                venue_value = venue_info['value']
                if 'oral' in venue_value.lower():
                    papers_by_type['Oral'].append(note)
                elif 'spotlight' in venue_value.lower():
                    papers_by_type['Spotlight'].append(note)
                elif 'poster' in venue_value.lower():
                    papers_by_type['Poster'].append(note)
    
    return papers_by_type

# Usage of the function
venue_id = "ICML.cc/2024/Conference"

# venue_id = "NeurIPS.cc/2023/Conference"
papers_by_type = fetch_and_categorize_papers(venue_id)

# Print the results to verify
# for paper_type, notes in papers_by_type.items():
#     print(f"\n{paper_type} Papers:")
#     if notes:
#         for note in notes[:5]:  # Limiting to first 5 papers for brevity
#             title = note.get('content', {}).get('title', 'No title available')
#             authors = ", ".join(note.get('content', {}).get('authors', []))
#             abstract = note.get('content', {}).get('abstract', 'No abstract available')
#             tldr = note.get('content', {}).get('TLDR', 'No TL;DR available')
#             keywords = note.get('content', {}).get('keywords', 'No keywords available')
#             link = f"https://openreview.net/forum?id={note['id']}"
#             print(f"Title: {title}")
#             print(f"Authors: {authors}")
#             print(f"Abstract: {abstract}")
#             print(f"TL;DR: {tldr}")
#             print(f"Keywords: {keywords}")
#             print(f"Link: {link}")
#             print("---")
#     else:
#         print("No papers found.")

# %%
for paper_type, notes in papers_by_type.items():
    print(f"\n{paper_type} Papers:")
    if notes:
        for note in notes: 
            title = note.get('content', {}).get('title', 'No title available').get('value')
            authors = ", ".join(note.get('content', {}).get('authors', []).get('value'))
            abstract = note.get('content', {}).get('abstract', 'No abstract available').get('value')

            tldr = note.get('content', {}).get('TLDR', '')
            if tldr:
                tldr = tldr['value']
            else:
                tldr = 'No TL;DR available'

            keywords = note.get('content', {}).get('keywords', 'No keywords available').get('value')
            keywords = '; '.join(keywords)


            if ('reasoning' in tldr.lower()) or ('reasoning' in keywords.lower()) or ('reasoning' in abstract.lower()) or ('reasoning' in title.lower()):
                # print(f"Reasoning Paper")

                # link = f"https://openreview.net/forum?id={note['id']}"
                print(f"Title: {title}")
                print(f"Authors: {authors}")
                # print(f"Abstract: {abstract}")
                print(f"TL;DR: {tldr}")
                print(f"Keywords: {keywords}")
                # print(f"Link: {link}")
                print("---")

# %%
import requests
import json

# Test the API endpoint directly and print a portion of the response
url = "https://api2.openreview.net/notes?content.venueid=ICLR.cc/2024/Conference"
response = requests.get(url)
data = response.json()

# Print the entire response to understand its structure
print(json.dumps(data, indent=4))

# Check if specific expected keys are present and print the first few entries if available
if 'notes' in data and data['notes']:
    for note in data['notes'][:5]:  # Print details of the first 5 entries
        print("Title:", note.get('content', {}).get('title', 'No title available'))
        print("Authors:", ", ".join(note.get('content', {}).get('authors', [])))
        print("Abstract:", note.get('content', {}).get('abstract', 'No abstract available'))
        print("Link:", f"https://openreview.net/forum?id={note['id']}")
        print("---")
else:
    print("No notes found in the data.")

# import requests
# import json

# # Request a broad set of data to understand its structure
# url = "https://api2.openreview.net/notes?content.venueid=ICLR.cc/2024/Conference"
# response = requests.get(url)
# data = response.json()

# # Print a comprehensive view of the first few entries to inspect the structure
# print(json.dumps(data['notes'][:5], indent=4))  # Print details of the first 5 entries

# %%
import requests
import json

# Request a broad set of data to understand its structure
url = "https://api2.openreview.net/notes?content.venueid=NeurIPS.cc/2023/Conference"
response = requests.get(url)
data = response.json()

# Print a comprehensive view of the first few entries to inspect the structure
print(json.dumps(data['notes'][:5], indent=4))  # Print details of the first 5 entries

# %%
import requests

url = "https://api.together.xyz/v1/chat/completions"

payload = {
    "model": "mistralai/Mixtral-8x7B-Instruct-v0.1",
    "temperature": 0.7,
    "frequency_penalty": 0,
    "presence_penalty": 0,
    "max_tokens": 512,
    "stop": ["</s>", "[/INST]"],
    "top_p": 0.7,
    "top_k": 50,
    "repetition_penalty": 1,
    "messages": [
        {
            "role": "system",
            "content": "You are a helpful travel agent"
        },
        {
            "role": "user",
            "content": "Tell me about San Francisco"
        }
    ]
}
headers = {
    "accept": "application/json",
    "content-type": "application/json",
    "Authorization": "Bearer 1940cc7aab91e20ee2f4d6d971dd8abe078db62293b29214485a956e193fb532"
}

response = requests.post(url, json=payload, headers=headers)

print(response.text)
